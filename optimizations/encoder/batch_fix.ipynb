ized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/ee1084b611a82b81557d1eaba741e58180195027resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/ee291f01b8579d8575c56f338c730d1eb1fae96eresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/eee8cbd6f3c41a747ccfbc3711e2e51619dae292resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/ef0103bea8564097bd40092886cc90b9d6b29b6eresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/efa9c5ceecb1926de2ea42424f1d539b43cc18ddresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f231089e34a08c800c88310670ad671a5fb3ecd4resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f298a4365f041a7df03a90a4b7ef3bbd4d4e8cfbresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f29ae4a323d6f24373c547e6eb7c10f5964d320dresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f2a354c4f079ee7f1b7348854bbd2c17e5d0edf3resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f37a5d43815e5264e0adfd37604a35c7118abcecresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f465e11d16a1d39926a083716eb94dee6803af6aresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f4d9d947df7775ea98ebc6917f884712d26d78d6resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f4ec1e9e3b07aa63dbd3c777035e748c02776571resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f555fe5f6959089d6631246f4c43b7d8f69b8f2aresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f5afcc2518a3dbc823233052ee718c7248c36f5eresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f5b1e7bd2510c54c41529492c6104a0dd6c6513dresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f5b590c7788ec0464b836312542836f40b0919deresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f5bb8aa73b18016a8e6ab270aa99c6533c9f8525resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f6394117879cceb6daafcc07a3c513b911a1d989resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f7348368316a9d174860ce74606b22aeae3d9429resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f816c1a6dbf871a08db54e378af8e230f680678cresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f89b6a80ee2194ae21429b42fad2de221bf24e14resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/f95acc0480956becec8502e0a87b6eed09a0f246resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/faac216832cb87b55bd9dd3a2ead8acfaf7c4710resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/fab80a4708659b5b85318ff7f94ab2e875976b0bresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/faf9b630885785a50b34ca2d6a1d30584be9847dresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/fbb0bce79f6356dcdaaacfa3fa418650c76206eeresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/fbf5f3910bef1a613d49759024336f97db8a2827resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/fc55e869a8d4891a9ead5546b14d2eaeef09ce2fresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/fd669ee7ee5d602347d4bb8091e9eb00c2d54c89resized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/feac0e37240b2a52c8d03fa72f9bb4e7c332784cresized_image.png
#   inflating: /content/sample_data/dataset/val/Vilsel/ff1f07d51e1d69cab4746beef968ff37821dab76resized_image.png

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from dataclasses import dataclass
import json
from typing import Dict, Tuple
import logging
import absl.logging
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Initialize ABSL logging
absl.logging.set_verbosity(absl.logging.ERROR)
logging.root.removeHandler(absl.logging._absl_handler)
absl.logging._warn_preinit_stderr = False

# Set random seeds
import random
random.seed(42)
tf.random.set_seed(42)
np.random.seed(42)

# Configure GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
    print(f"GPU(s) detected: {len(physical_devices)}")
else:
    print("No GPU detected, using CPU")

@dataclass
class StyleGANConfig:
    image_size: int = 128
    latent_dim: int = 64
    mapping_layers: int = 2
    style_dim: int = 64
    num_channels: int = 1
    batch_size: int = 32  # Adjust the batch size here
    learning_rate: float = 0.0001
    initial_learning_rate: float = 0.0001
    decay_steps: int = 1000
    decay_rate: float = 0.95
    epochs: int = 100
    checkpoint_dir: str = './checkpoints'
    gradient_clip: float = 1.0
    gradient_penalty_weight: float = 10.0
    diversity_weight: float = 0.1
    num_variants: int = 4
    dropout_rate: float = 0.3  # randomly disables neuron during training 0.3 is default alternative is L2
    early_stopping_patience: int = 5

config = StyleGANConfig()

def preprocess_dataset(train_data_dir: str, val_data_dir: str, image_size: int, batch_size: int, test_size: float = 0.2):
    try:
        class_names = sorted([d.name for d in Path(train_data_dir).iterdir() if d.is_dir()])
        print(f"Found classes: {class_names}")

        train_dataset = tf.keras.utils.image_dataset_from_directory(
            train_data_dir,
            labels='inferred',
            label_mode='categorical',
            class_names=class_names,
            color_mode='rgb',
            batch_size=None,
            image_size=(image_size, image_size),
            shuffle=True,
            seed=42
        )

        val_dataset = tf.keras.utils.image_dataset_from_directory(
            val_data_dir,
            labels='inferred',
            label_mode='categorical',
            class_names=class_names,
            color_mode='rgb',
            batch_size=None,
            image_size=(image_size, image_size),
            shuffle=True,
            seed=42
        )

        # Normalize the datasets
        def normalize_image(image, label):
            image = tf.cast(image, tf.float32)
            image = tf.image.rgb_to_grayscale(image)
            image = (image / 127.5) - 1.0
            return image, label

        train_dataset = train_dataset.map(normalize_image, num_parallel_calls=tf.data.AUTOTUNE)
        val_dataset = val_dataset.map(normalize_image, num_parallel_calls=tf.data.AUTOTUNE)

        # Batch and prefetch the datasets
        train_dataset = train_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
        val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

        return train_dataset, val_dataset, class_names

    except Exception as e:
        print(f"Error in dataset preprocessing: {str(e)}")
        raise

class MalwareStyleGAN:
    def __init__(self, config: StyleGANConfig, num_classes: int):
        self.config = config
        self.num_classes = num_classes

        self.mapping_network = self.build_mapping_network()
        self.generator = self.build_memory_efficient_generator()
        self.encoder = self.build_encoder()
        self.discriminator = self.build_memory_efficient_discriminator()

        self.learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=config.initial_learning_rate,
            decay_steps=config.decay_steps,
            decay_rate=config.decay_rate
        )

        self.d_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.g_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.m_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.e_optimizer = tf.keras.optimizers.Adam(self.learning_rate)

        dummy_input = tf.zeros((1, config.latent_dim))
        dummy_label = tf.zeros((1, num_classes))
        self._initialize_optimizers(dummy_input, dummy_label)

    def _initialize_optimizers(self, dummy_input, dummy_label):
        with tf.GradientTape(persistent=True) as tape:
            w = self.mapping_network([dummy_input, dummy_label])
            fake = self.generator(w)
            _ = self.discriminator([fake, dummy_label])
            _ = self.encoder(fake)

        self.d_optimizer.apply_gradients(
            zip([tf.zeros_like(v) for v in self.discriminator.trainable_variables],
                self.discriminator.trainable_variables))
        self.g_optimizer.apply_gradients(
            zip([tf.zeros_like(v) for v in self.generator.trainable_variables],
                self.generator.trainable_variables))
        self.m_optimizer.apply_gradients(
            zip([tf.zeros_like(v) for v in self.mapping_network.trainable_variables],
                self.mapping_network.trainable_variables))
        self.e_optimizer.apply_gradients(
            zip([tf.zeros_like(v) for v in self.encoder.trainable_variables],
                self.encoder.trainable_variables))

    def build_mapping_network(self):
        z = tf.keras.layers.Input(shape=(self.config.latent_dim,))
        y = tf.keras.layers.Input(shape=(self.num_classes,))

        x = tf.keras.layers.Concatenate()([z, y])

        for _ in range(self.config.mapping_layers):
            x = tf.keras.layers.Dense(self.config.style_dim)(x)
            x = tf.keras.layers.LeakyReLU(0.2)(x)

        return tf.keras.Model([z, y], x, name='mapping_network')

    def build_memory_efficient_generator(self):
        style = tf.keras.layers.Input(shape=(self.config.style_dim,))

        x = tf.keras.layers.Dense(8 * 8 * 256)(style)
        x = tf.keras.layers.Reshape((8, 8, 256))(x)

        channels = [256, 128, 64, 32]
        for ch in channels:
            x = tf.keras.layers.UpSampling2D()(x)
            x = tf.keras.layers.Conv2D(ch, 3, padding='same',
                                     kernel_initializer='he_normal')(x)
            x = tf.keras.layers.LeakyReLU(0.2)(x)
            x = tf.keras.layers.BatchNormalization(momentum=0.8)(x)

        x = tf.keras.layers.Conv2D(self.config.num_channels, 1,
                                  activation='tanh')(x)

        return tf.keras.Model(style, x, name='generator')

    def build_encoder(self):
        img = tf.keras.layers.Input(shape=(None, None, self.config.num_channels))

        x = img
        channels = [32, 64, 128, 256, 512]

        for ch in channels:
            x = tf.keras.layers.Conv2D(ch, 3, strides=2, padding='same')(x)
            x = tf.keras.layers.LeakyReLU(0.2)(x)
            x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dense(self.config.style_dim)(x)

        return tf.keras.Model(img, x, name='encoder')

    def build_memory_efficient_discriminator(self):
        img = tf.keras.layers.Input(shape=(self.config.image_size,
                                          self.config.image_size,
                                          self.config.num_channels))
        label = tf.keras.layers.Input(shape=(self.num_classes,))

        x = img
        channels = [32, 64, 128, 256]

        for ch in channels:
            x = tf.keras.layers.Conv2D(ch, 3, strides=2, padding='same')(x)
            x = tf.keras.layers.LeakyReLU(0.2)(x)
            x = tf.keras.layers.Dropout(self.config.dropout_rate)(x)

        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Concatenate()([x, label])
        x = tf.keras.layers.Dense(256)(x)
        x = tf.keras.layers.LeakyReLU(0.2)(x)
        x = tf.keras.layers.Dropout(self.config.dropout_rate)(x)
        x = tf.keras.layers.Dense(self.config.num_variants)(x)

        return tf.keras.Model([img, label], x, name='discriminator')

    def generate_variants(self, z, labels, num_variants):
        variants = []
        latent_codes = []

        w_base = self.mapping_network([z, labels])

        for _ in range(num_variants):
            if tf.random.uniform([]) < self.config.style_mixing_prob:
                z_new = tf.random.normal((tf.shape(z)))
                w_new = self.mapping_network([z_new, labels])

                mixing_weights = tf.random.uniform([tf.shape(w_base)[1]], 0, 1)
                w_mixed = w_base * mixing_weights + w_new * (1 - mixing_weights)
                latent_codes.append(w_mixed)
            else:
                w_perturbed = w_base + tf.random.normal(tf.shape(w_base)) * 0.1
                latent_codes.append(w_perturbed)

            variant = self.generator(latent_codes[-1])
            variants.append(variant)

        return variants, latent_codes

    @tf.function
    def train_step(self, real_images, labels):
        batch_size = tf.shape(real_images)[0]

        with tf.GradientTape(persistent=True) as tape:
            real_images = tf.cast(real_images, tf.float32)
            labels = tf.cast(labels, tf.float32)

            z_base = tf.random.normal((batch_size, self.config.latent_dim),
                                    dtype=tf.float32,
                                    stddev=1.0)
            w_base = self.mapping_network([z_base, labels])

            variants_list = []
            w_variants_list = []

            base_variant = self.generator(w_base)
            variants_list.append(base_variant)
            w_variants_list.append(w_base)

            for _ in range(self.config.num_variants - 1):
                z_new = tf.random.normal((batch_size, self.config.latent_dim),
                                       dtype=tf.float32,
                                       stddev=0.5)
                w_new = self.mapping_network([z_new, labels])
                w_mixed = w_base * 0.7 + w_new * 0.3
                variant = self.generator(w_mixed)
                variants_list.append(variant)
                w_variants_list.append(w_mixed)

            variants_stacked = tf.stack(variants_list)
            variants_stacked = tf.clip_by_value(variants_stacked, -1.0, 1.0)

            variant_logits = self.discriminator([
                tf.reshape(variants_stacked,
                          [-1, self.config.image_size, self.config.image_size, self.config.num_channels]),
                tf.tile(labels, [self.config.num_variants, 1])
            ])

            variant_labels = tf.cast(tf.eye(self.config.num_variants), dtype=tf.float32)
            variant_labels = tf.tile(variant_labels, [batch_size, 1])

            variant_loss = tf.reduce_mean(
                tf.nn.softmax_cross_entropy_with_logits(
                    labels=variant_labels,
                    logits=variant_logits
                ))

            diversity_loss = -tf.reduce_mean(
                tf.abs(variants_stacked[:, None] - variants_stacked[None, :])
            ) * 0.1

            generator_loss = -variant_loss + self.config.diversity_weight * diversity_loss
            encoder_loss = tf.reduce_mean(tf.square(self.encoder(real_images) - w_base))

        gradients = [
            (variant_loss, self.discriminator.trainable_variables, self.d_optimizer),
            (generator_loss, self.generator.trainable_variables, self.g_optimizer),
            (generator_loss, self.mapping_network.trainable_variables, self.m_optimizer),
            (encoder_loss, self.encoder.trainable_variables, self.e_optimizer)
        ]

        for loss, vars, optimizer in gradients:
            grads = tape.gradient(loss, vars)
            if grads is not None:
                clipped_grads, _ = tf.clip_by_global_norm(grads, self.config.gradient_clip)
                optimizer.apply_gradients(zip(clipped_grads, vars))

        del tape

        return {
            'variant_loss': variant_loss,
            'generator_loss': generator_loss,
            'encoder_loss': encoder_loss,
            'diversity_loss': diversity_loss
        }

    def save_model(self, path: str, class_indices: Dict):
        Path(path).mkdir(parents=True, exist_ok=True)

        self.mapping_network.save(os.path.join(path, 'mapping_network.keras'))
        self.generator.save(os.path.join(path, 'generator.keras'))
        self.encoder.save(os.path.join(path, 'encoder.keras'))
        self.discriminator.save(os.path.join(path, 'discriminator.keras'))

        with open(os.path.join(path, 'class_indices.json'), 'w') as f:
            json.dump(class_indices, f)

    def load_model(self, path: str):
        self.mapping_network = tf.keras.models.load_model(
            os.path.join(path, 'mapping_network.keras'))
        self.generator = tf.keras.models.load_model(
            os.path.join(path, 'generator.keras'))
        self.encoder = tf.keras.models.load_model(
            os.path.join(path, 'encoder.keras'))
        self.discriminator = tf.keras.models.load_model(
            os.path.join(path, 'discriminator.keras'))

        # Reinitialize optimizers with the loaded model's variables
        self.d_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.g_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.m_optimizer = tf.keras.optimizers.Adam(self.learning_rate)
        self.e_optimizer = tf.keras.optimizers.Adam(self.learning_rate)

def build_malware_detection_model(input_shape, num_classes):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=input_shape),
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def train_malware_detection_model(train_ds, val_ds, num_classes, epochs=10):
    input_shape = (config.image_size, config.image_size, config.num_channels)
    model = build_malware_detection_model(input_shape, num_classes)

    model.fit(train_ds, validation_data=val_ds, epochs=epochs)
    model.save('malware_detection_model.h5')

def evaluate_model(model, test_ds, class_indices):
    y_true = []
    y_pred = []

    for images, labels in test_ds:
        predictions = model.predict(images)
        y_true.extend(np.argmax(labels.numpy(), axis=1))
        y_pred.extend(np.argmax(predictions, axis=1))

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    conf_matrix = confusion_matrix(y_true, y_pred)
    class_report = classification_report(y_true, y_pred, target_names=class_indices.keys())

    print(f"Overall Accuracy: {accuracy:.4f}")
    print(f"Overall Precision: {precision:.4f}")
    print(f"Confusion Matrix:\n{conf_matrix}")
    print(f"Classification Report:\n{class_report}")

    return accuracy, precision, conf_matrix, class_report

def load_latest_model(checkpoint_dir):
    checkpoints = list(Path(checkpoint_dir).glob('epoch_*'))
    if not checkpoints:
        print("No checkpoints found.")
        return None

    latest_checkpoint = max(checkpoints, key=lambda x: int(x.name.split('_')[-1]))
    print(f"Loading model from checkpoint: {latest_checkpoint}")
    return latest_checkpoint

def main():
    physical_devices = tf.config.list_physical_devices('GPU')
    if (physical_devices):
        print(f"GPU(s) detected: {len(physical_devices)}")
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
    else:
        print("No GPU detected, using CPU")

    train_path = os.path.join('sample_data', 'dataset', 'train')
    val_path = os.path.join('sample_data', 'dataset', 'val')

    os.makedirs(config.checkpoint_dir, exist_ok=True)
    os.makedirs('samples', exist_ok=True)

    # Adjust the batch size here
    train_ds, val_ds, class_names = preprocess_dataset(train_path, val_path, config.image_size, config.batch_size)

    raw_ds = tf.keras.utils.image_dataset_from_directory(
        train_path,
        label_mode='categorical'
    )
    class_indices = {name: i for i, name in enumerate(raw_ds.class_names)}

    model = MalwareStyleGAN(config, len(class_indices))

    # Load the latest model if it exists
    latest_checkpoint = load_latest_model(config.checkpoint_dir)
    if latest_checkpoint:
        model.load_model(latest_checkpoint)

    best_loss = float('inf')
    patience_counter = 0

    for epoch in range(config.epochs):
        print(f"Epoch {epoch+1}/{config.epochs}")

        epoch_losses = []
        for batch_idx, (images, labels) in enumerate(train_ds):
            try:
                losses = model.train_step(images, labels)
                epoch_losses.append(losses)

                if batch_idx % 10 == 0:
                    print(f"Batch {batch_idx}: variant_loss={losses['variant_loss']:.4f}, "
                          f"generator_loss={losses['generator_loss']:.4f}, "
                          f"encoder_loss={losses['encoder_loss']:.4f}")

            except tf.errors.ResourceExhaustedError:
                print("GPU memory exhausted, skipping batch")
                tf.keras.backend.clear_session()
                continue

        avg_losses = {k: float(np.mean([x[k] for x in epoch_losses]))
                     for k in epoch_losses[0].keys()}
        print(f"Epoch {epoch+1} Averages:")
        for k, v in avg_losses.items():
            print(f"{k}: {v:.4f}")

        checkpoint_path = os.path.join(config.checkpoint_dir, f'epoch_{epoch+1}')
        model.save_model(checkpoint_path, class_indices)
        print(f"Saved checkpoint at {checkpoint_path}")

        if epoch % 10 == 0:
            z = tf.random.normal((4, config.latent_dim))
            labels = tf.one_hot(range(4), len(class_indices))
            w = model.mapping_network([z, labels])
            fake_images = model.generator(w)

            plt.figure(figsize=(10, 10))
            for i in range(4):
                plt.subplot(2, 2, i+1)
                plt.imshow(fake_images[i] * 0.5 + 0.5, cmap='gray')
                plt.axis('off')
            plt.savefig(f'samples/epoch_{epoch+1}.png')
            plt.close()

        current_loss = avg_losses['variant_loss']
        if current_loss < best_loss:
            best_loss = current_loss
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= config.early_stopping_patience:
            print("Early stopping triggered")
            break

        # Evaluate the model every 3 epochs
        if (epoch + 1) % 3 == 0:
            detection_model = build_malware_detection_model(
                (config.image_size, config.image_size, config.num_channels),
                len(class_indices)
            )
            detection_model.fit(train_ds, validation_data=val_ds, epochs=1)
            accuracy, precision, conf_matrix, class_report = evaluate_model(detection_model, val_ds, class_indices)
            print(f"Epoch {epoch+1} Evaluation Metrics:")
            print(f"Accuracy: {accuracy:.4f}")
            print(f"Precision: {precision:.4f}")
            print(f"Confusion Matrix:\n{conf_matrix}")
            print(f"Classification Report:\n{class_report}")

    # Train the malware detection model
    train_malware_detection_model(train_ds, val_ds, len(class_indices), epochs=10)

if __name__ == "__main__":
    main()
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x797b47cc36d0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# GPU(s) detected: 1
# GPU(s) detected: 1
# Found classes: ['Adposhel', 'Agent', 'Allaple', 'Alueron.gen!J', 'Amonetize', 'Androm', 'Autorun', 'Benign', 'BrowseFox', 'C2LOP.gen!g', 'Dialplatform.B', 'Dinwod', 'Elex', 'Expiro', 'Fakerean', 'Fasong', 'HackKMS', 'Hlux', 'Injector', 'InstallCore', 'Lolyda.AA1', 'Lolyda.AA2', 'MultiPlug', 'Neoreklami', 'Neshta', 'Regrun', 'Sality', 'Snarasite', 'Stantinko', 'VBA', 'VBKrypt', 'Vilsel']
# Found 10224 files belonging to 32 classes.
# Found 4087 files belonging to 32 classes.
# Found 10224 files belonging to 32 classes.
# No checkpoints found.
# Epoch 1/100
# Batch 0: variant_loss=1.3911, generator_loss=-1.3911, encoder_loss=0.2310
# Batch 10: variant_loss=1.3920, generator_loss=-1.3922, encoder_loss=0.1980
# Batch 20: variant_loss=1.3916, generator_loss=-1.3918, encoder_loss=0.1645
# Batch 30: variant_loss=1.3851, generator_loss=-1.3854, encoder_loss=0.1593
# Batch 40: variant_loss=1.3758, generator_loss=-1.3762, encoder_loss=0.1463
# Batch 50: variant_loss=1.3804, generator_loss=-1.3808, encoder_loss=0.1399
# Batch 60: variant_loss=1.3894, generator_loss=-1.3898, encoder_loss=0.1446
# Batch 70: variant_loss=1.3802, generator_loss=-1.3806, encoder_loss=0.1560
# Batch 80: variant_loss=1.3916, generator_loss=-1.3920, encoder_loss=0.1572
# Batch 90: variant_loss=1.3794, generator_loss=-1.3799, encoder_loss=0.1511
# Batch 100: variant_loss=1.3860, generator_loss=-1.3866, encoder_loss=0.1401
# Batch 110: variant_loss=1.3700, generator_loss=-1.3705, encoder_loss=0.1529
# Batch 120: variant_loss=1.3877, generator_loss=-1.3882, encoder_loss=0.1647
# Batch 130: variant_loss=1.3909, generator_loss=-1.3915, encoder_loss=0.1649
# Batch 140: variant_loss=1.3889, generator_loss=-1.3897, encoder_loss=0.1571
# Batch 150: variant_loss=1.3805, generator_loss=-1.3813, encoder_loss=0.1566
# Batch 160: variant_loss=1.3918, generator_loss=-1.3925, encoder_loss=0.1562
# Batch 170: variant_loss=1.3816, generator_loss=-1.3826, encoder_loss=0.1408
# Batch 180: variant_loss=1.3896, generator_loss=-1.3905, encoder_loss=0.1542
# Batch 190: variant_loss=1.3930, generator_loss=-1.3939, encoder_loss=0.1494
# Batch 200: variant_loss=1.3835, generator_loss=-1.3844, encoder_loss=0.1569
# Batch 210: variant_loss=1.3813, generator_loss=-1.3823, encoder_loss=0.1415
# Batch 220: variant_loss=1.3824, generator_loss=-1.3836, encoder_loss=0.1545
# Batch 230: variant_loss=1.3806, generator_loss=-1.3816, encoder_loss=0.1478
# Batch 240: variant_loss=1.3901, generator_loss=-1.3913, encoder_loss=0.1379
# Batch 250: variant_loss=1.3988, generator_loss=-1.4004, encoder_loss=0.1485
# Batch 260: variant_loss=1.3871, generator_loss=-1.3878, encoder_loss=0.1627
# Batch 270: variant_loss=1.3802, generator_loss=-1.3807, encoder_loss=0.1423
# Batch 280: variant_loss=1.3801, generator_loss=-1.3811, encoder_loss=0.1520
# Batch 290: variant_loss=1.3844, generator_loss=-1.3856, encoder_loss=0.1432
# Batch 300: variant_loss=1.3808, generator_loss=-1.3822, encoder_loss=0.1637
# Batch 310: variant_loss=1.3897, generator_loss=-1.3907, encoder_loss=0.1400
# Epoch 1 Averages:
# variant_loss: 1.3871
# generator_loss: -1.3878
# encoder_loss: 0.1535
# diversity_loss: -0.0077
# Saved checkpoint at ./checkpoints/epoch_1
# Epoch 2/100
# Batch 0: variant_loss=1.3957, generator_loss=-1.3973, encoder_loss=0.1462
# Batch 10: variant_loss=1.3784, generator_loss=-1.3789, encoder_loss=0.1427
# Batch 20: variant_loss=1.3962, generator_loss=-1.3963, encoder_loss=0.1494
# Batch 30: variant_loss=1.3953, generator_loss=-1.3953, encoder_loss=0.1350
# Batch 40: variant_loss=1.3935, generator_loss=-1.3935, encoder_loss=0.1477
# Batch 50: variant_loss=1.3835, generator_loss=-1.3835, encoder_loss=0.1607
# Batch 60: variant_loss=1.3843, generator_loss=-1.3843, encoder_loss=0.1382
# Batch 70: variant_loss=1.3893, generator_loss=-1.3893, encoder_loss=0.1540
# Batch 80: variant_loss=1.3957, generator_loss=-1.3957, encoder_loss=0.1447
# Batch 90: variant_loss=1.3801, generator_loss=-1.3801, encoder_loss=0.1610
# Batch 100: variant_loss=1.3937, generator_loss=-1.3938, encoder_loss=0.1521
# Batch 110: variant_loss=1.3911, generator_loss=-1.3912, encoder_loss=0.1541
# Batch 120: variant_loss=1.3864, generator_loss=-1.3865, encoder_loss=0.1504
# Batch 130: variant_loss=1.3803, generator_loss=-1.3803, encoder_loss=0.1570
# Batch 140: variant_loss=1.3924, generator_loss=-1.3925, encoder_loss=0.1406
# Batch 150: variant_loss=1.3876, generator_loss=-1.3877, encoder_loss=0.1540
# Batch 160: variant_loss=1.3788, generator_loss=-1.3789, encoder_loss=0.1437
# Batch 170: variant_loss=1.3862, generator_loss=-1.3863, encoder_loss=0.1548
# Batch 180: variant_loss=1.3776, generator_loss=-1.3778, encoder_loss=0.1495
# Batch 190: variant_loss=1.3882, generator_loss=-1.3884, encoder_loss=0.1478
# Batch 200: variant_loss=1.3869, generator_loss=-1.3871, encoder_loss=0.1302
# Batch 210: variant_loss=1.3897, generator_loss=-1.3899, encoder_loss=0.1529
# Batch 220: variant_loss=1.3973, generator_loss=-1.3975, encoder_loss=0.1526
# Batch 230: variant_loss=1.3937, generator_loss=-1.3940, encoder_loss=0.1545
# Batch 240: variant_loss=1.3866, generator_loss=-1.3869, encoder_loss=0.1503
# Batch 250: variant_loss=1.3882, generator_loss=-1.3885, encoder_loss=0.1468
# Batch 260: variant_loss=1.3949, generator_loss=-1.3952, encoder_loss=0.1423
# Batch 270: variant_loss=1.3850, generator_loss=-1.3855, encoder_loss=0.1280
# Batch 280: variant_loss=1.3833, generator_loss=-1.3838, encoder_loss=0.1465
# Batch 290: variant_loss=1.3928, generator_loss=-1.3933, encoder_loss=0.1417
# Batch 300: variant_loss=1.3838, generator_loss=-1.3843, encoder_loss=0.1625
# Batch 310: variant_loss=1.3805, generator_loss=-1.3811, encoder_loss=0.1524
# Epoch 2 Averages:
# variant_loss: 1.3874
# generator_loss: -1.3876
# encoder_loss: 0.1501
# diversity_loss: -0.0022
# Saved checkpoint at ./checkpoints/epoch_2
# Epoch 3/100
# Batch 0: variant_loss=1.3773, generator_loss=-1.3779, encoder_loss=0.1517
# Batch 10: variant_loss=1.3854, generator_loss=-1.3859, encoder_loss=0.1480
# Batch 20: variant_loss=1.3933, generator_loss=-1.3939, encoder_loss=0.1463
# Batch 30: variant_loss=1.3898, generator_loss=-1.3904, encoder_loss=0.1531
# Batch 40: variant_loss=1.3788, generator_loss=-1.3794, encoder_loss=0.1315
# Batch 50: variant_loss=1.3839, generator_loss=-1.3845, encoder_loss=0.1483
# Batch 60: variant_loss=1.3831, generator_loss=-1.3838, encoder_loss=0.1512
# Batch 70: variant_loss=1.3991, generator_loss=-1.4001, encoder_loss=0.1247
# Batch 80: variant_loss=1.3814, generator_loss=-1.3825, encoder_loss=0.1581
# Batch 90: variant_loss=1.3861, generator_loss=-1.3872, encoder_loss=0.1408
# Batch 100: variant_loss=1.3849, generator_loss=-1.3861, encoder_loss=0.1410
# Batch 110: variant_loss=1.3940, generator_loss=-1.3954, encoder_loss=0.1496
# Batch 120: variant_loss=1.3842, generator_loss=-1.3858, encoder_loss=0.1312
# Batch 130: variant_loss=1.3905, generator_loss=-1.3925, encoder_loss=0.1542
# Batch 140: variant_loss=1.3889, generator_loss=-1.3915, encoder_loss=0.1421
# Batch 150: variant_loss=1.3833, generator_loss=-1.3860, encoder_loss=0.1508
# Batch 160: variant_loss=1.3777, generator_loss=-1.3802, encoder_loss=0.1456
# Batch 170: variant_loss=1.3953, generator_loss=-1.3973, encoder_loss=0.1492
# Batch 180: variant_loss=1.3897, generator_loss=-1.3925, encoder_loss=0.1520
# Batch 190: variant_loss=1.3807, generator_loss=-1.3841, encoder_loss=0.1341
# Batch 200: variant_loss=1.3946, generator_loss=-1.3971, encoder_loss=0.1438
# Batch 210: variant_loss=1.3877, generator_loss=-1.3906, encoder_loss=0.1242
# Batch 220: variant_loss=1.3898, generator_loss=-1.3924, encoder_loss=0.1454
# Batch 230: variant_loss=1.3925, generator_loss=-1.3958, encoder_loss=0.1535
# Batch 240: variant_loss=1.3800, generator_loss=-1.3838, encoder_loss=0.1524
# Batch 250: variant_loss=1.3879, generator_loss=-1.3922, encoder_loss=0.1446
# Batch 260: variant_loss=1.3839, generator_loss=-1.3877, encoder_loss=0.1322
# Batch 270: variant_loss=1.3822, generator_loss=-1.3856, encoder_loss=0.1631
# Batch 280: variant_loss=1.3927, generator_loss=-1.3964, encoder_loss=0.1380
# Batch 290: variant_loss=1.3852, generator_loss=-1.3897, encoder_loss=0.1271
# Batch 300: variant_loss=1.3941, generator_loss=-1.3978, encoder_loss=0.1466
# Batch 310: variant_loss=1.3867, generator_loss=-1.3910, encoder_loss=0.1368
# Epoch 3 Averages:
# variant_loss: 1.3876
# generator_loss: -1.3900
# encoder_loss: 0.1486
# diversity_loss: -0.0234
# Saved checkpoint at ./checkpoints/epoch_3
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 48s 135ms/step - accuracy: 0.5483 - loss: 1.7832 - val_accuracy: 0.8723 - val_loss: 0.4716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Overall Accuracy: 0.8723
# Overall Precision: 0.8763
# Confusion Matrix:
# [[141   0   0 ...   0   0   0]
#  [  0  71   0 ...   0   2   0]
#  [  0   1 107 ...   0   0   0]
#  ...
#  [  0   0   0 ... 150   0   0]
#  [  0   0   0 ...   0 128   0]
#  [  0   0   0 ...   0   0 146]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#       Adposhel       0.94      0.98      0.96       144
#          Agent       0.68      0.59      0.63       120
#        Allaple       0.97      0.84      0.90       128
#  Alueron.gen!J       0.78      1.00      0.88        25
#      Amonetize       0.99      0.86      0.92       147
#         Androm       0.61      0.97      0.75       150
#        Autorun       0.66      0.73      0.69       146
#         Benign       0.85      0.82      0.83       208
#      BrowseFox       0.91      0.90      0.91       143
#    C2LOP.gen!g       0.58      1.00      0.74        25
# Dialplatform.B       1.00      1.00      1.00        25
#         Dinwod       0.85      0.95      0.90       149
#           Elex       0.91      0.95      0.93       150
#         Expiro       0.65      0.70      0.67       151
#       Fakerean       1.00      0.99      0.99        75
#         Fasong       0.97      1.00      0.99       150
#        HackKMS       0.99      0.99      0.99       149
#           Hlux       0.94      0.99      0.97       150
#       Injector       0.95      0.68      0.79       145
#    InstallCore       1.00      0.98      0.99       150
#     Lolyda.AA1       1.00      1.00      1.00        60
#     Lolyda.AA2       1.00      1.00      1.00        25
#      MultiPlug       0.88      0.87      0.88       149
#     Neoreklami       0.97      0.98      0.97       150
#         Neshta       0.58      0.43      0.49       147
#         Regrun       0.99      0.99      0.99       135
#         Sality       0.71      0.40      0.51       149
#      Snarasite       0.99      1.00      0.99       150
#      Stantinko       0.92      0.97      0.95       150
#            VBA       0.97      1.00      0.99       150
#        VBKrypt       0.80      0.88      0.84       146
#         Vilsel       1.00      1.00      1.00       146
#
#       accuracy                           0.87      4087
#      macro avg       0.88      0.89      0.88      4087
#   weighted avg       0.88      0.87      0.87      4087
#
# Epoch 3 Evaluation Metrics:
# Accuracy: 0.8723
# Precision: 0.8763
# Confusion Matrix:
# [[141   0   0 ...   0   0   0]
#  [  0  71   0 ...   0   2   0]
#  [  0   1 107 ...   0   0   0]
#  ...
#  [  0   0   0 ... 150   0   0]
#  [  0   0   0 ...   0 128   0]
#  [  0   0   0 ...   0   0 146]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#       Adposhel       0.94      0.98      0.96       144
#          Agent       0.68      0.59      0.63       120
#        Allaple       0.97      0.84      0.90       128
#  Alueron.gen!J       0.78      1.00      0.88        25
#      Amonetize       0.99      0.86      0.92       147
#         Androm       0.61      0.97      0.75       150
#        Autorun       0.66      0.73      0.69       146
#         Benign       0.85      0.82      0.83       208
#      BrowseFox       0.91      0.90      0.91       143
#    C2LOP.gen!g       0.58      1.00      0.74        25
# Dialplatform.B       1.00      1.00      1.00        25
#         Dinwod       0.85      0.95      0.90       149
#           Elex       0.91      0.95      0.93       150
#         Expiro       0.65      0.70      0.67       151
#       Fakerean       1.00      0.99      0.99        75
#         Fasong       0.97      1.00      0.99       150
#        HackKMS       0.99      0.99      0.99       149
#           Hlux       0.94      0.99      0.97       150
#       Injector       0.95      0.68      0.79       145
#    InstallCore       1.00      0.98      0.99       150
#     Lolyda.AA1       1.00      1.00      1.00        60
#     Lolyda.AA2       1.00      1.00      1.00        25
#      MultiPlug       0.88      0.87      0.88       149
#     Neoreklami       0.97      0.98      0.97       150
#         Neshta       0.58      0.43      0.49       147
#         Regrun       0.99      0.99      0.99       135
#         Sality       0.71      0.40      0.51       149
#      Snarasite       0.99      1.00      0.99       150
#      Stantinko       0.92      0.97      0.95       150
#            VBA       0.97      1.00      0.99       150
#        VBKrypt       0.80      0.88      0.84       146
#         Vilsel       1.00      1.00      1.00       146
#
#       accuracy                           0.87      4087
#      macro avg       0.88      0.89      0.88      4087
#   weighted avg       0.88      0.87      0.87      4087
#
# Epoch 4/100
# Batch 0: variant_loss=1.3962, generator_loss=-1.4000, encoder_loss=0.1465
# Batch 10: variant_loss=1.3821, generator_loss=-1.3858, encoder_loss=0.1399
# Batch 20: variant_loss=1.3865, generator_loss=-1.3908, encoder_loss=0.1392
# Batch 30: variant_loss=1.3899, generator_loss=-1.3935, encoder_loss=0.1717
# Batch 40: variant_loss=1.3842, generator_loss=-1.3888, encoder_loss=0.1556
# Batch 50: variant_loss=1.3942, generator_loss=-1.3984, encoder_loss=0.1612
# Batch 60: variant_loss=1.3762, generator_loss=-1.3800, encoder_loss=0.1440
# Batch 70: variant_loss=1.3944, generator_loss=-1.3993, encoder_loss=0.1323
# Batch 80: variant_loss=1.3853, generator_loss=-1.3897, encoder_loss=0.1577
# Batch 90: variant_loss=1.3915, generator_loss=-1.3954, encoder_loss=0.1417
# Batch 100: variant_loss=1.3891, generator_loss=-1.3938, encoder_loss=0.1463
# Batch 110: variant_loss=1.3877, generator_loss=-1.3922, encoder_loss=0.1385
# Batch 120: variant_loss=1.3881, generator_loss=-1.3925, encoder_loss=0.1416
# Batch 130: variant_loss=1.3858, generator_loss=-1.3909, encoder_loss=0.1642
# Batch 140: variant_loss=1.3836, generator_loss=-1.3888, encoder_loss=0.1589
# Batch 150: variant_loss=1.3858, generator_loss=-1.3908, encoder_loss=0.1726
# Batch 160: variant_loss=1.3930, generator_loss=-1.3988, encoder_loss=0.1611
# Batch 170: variant_loss=1.3923, generator_loss=-1.3973, encoder_loss=0.1441
# Batch 180: variant_loss=1.3894, generator_loss=-1.3936, encoder_loss=0.1384
# Batch 190: variant_loss=1.3911, generator_loss=-1.3955, encoder_loss=0.1484
# Batch 200: variant_loss=1.3850, generator_loss=-1.3895, encoder_loss=0.1358
# Batch 210: variant_loss=1.3869, generator_loss=-1.3908, encoder_loss=0.1704
# Batch 220: variant_loss=1.3798, generator_loss=-1.3847, encoder_loss=0.1463
# Batch 230: variant_loss=1.3911, generator_loss=-1.3950, encoder_loss=0.1443
# Batch 240: variant_loss=1.3890, generator_loss=-1.3935, encoder_loss=0.1519
# Batch 250: variant_loss=1.3876, generator_loss=-1.3919, encoder_loss=0.1385
# Batch 260: variant_loss=1.3865, generator_loss=-1.3901, encoder_loss=0.1614
# Batch 270: variant_loss=1.3885, generator_loss=-1.3932, encoder_loss=0.1556
# Batch 280: variant_loss=1.3867, generator_loss=-1.3910, encoder_loss=0.1563
# Batch 290: variant_loss=1.3826, generator_loss=-1.3872, encoder_loss=0.1418
# Batch 300: variant_loss=1.3925, generator_loss=-1.3968, encoder_loss=0.1539
# Batch 310: variant_loss=1.3797, generator_loss=-1.3844, encoder_loss=0.1475
# Epoch 4 Averages:
# variant_loss: 1.3865
# generator_loss: -1.3910
# encoder_loss: 0.1482
# diversity_loss: -0.0453
# Saved checkpoint at ./checkpoints/epoch_4
# Epoch 5/100
# Batch 0: variant_loss=1.3801, generator_loss=-1.3839, encoder_loss=0.1459
# Batch 10: variant_loss=1.3841, generator_loss=-1.3890, encoder_loss=0.1388
# Batch 20: variant_loss=1.4107, generator_loss=-1.4151, encoder_loss=0.1436
# Batch 30: variant_loss=1.3796, generator_loss=-1.3846, encoder_loss=0.1360
# Batch 40: variant_loss=1.3835, generator_loss=-1.3879, encoder_loss=0.1304
# Batch 50: variant_loss=1.3987, generator_loss=-1.4031, encoder_loss=0.1335
# Batch 60: variant_loss=1.3819, generator_loss=-1.3852, encoder_loss=0.1334
# Batch 70: variant_loss=1.3772, generator_loss=-1.3813, encoder_loss=0.1486
# Batch 80: variant_loss=1.3913, generator_loss=-1.3959, encoder_loss=0.1226
# Batch 90: variant_loss=1.3842, generator_loss=-1.3885, encoder_loss=0.1517
# Batch 100: variant_loss=1.3884, generator_loss=-1.3932, encoder_loss=0.1408
# Batch 110: variant_loss=1.3801, generator_loss=-1.3846, encoder_loss=0.1584
# Batch 120: variant_loss=1.3792, generator_loss=-1.3844, encoder_loss=0.1492
# Batch 130: variant_loss=1.4007, generator_loss=-1.4055, encoder_loss=0.1448
# Batch 140: variant_loss=1.3887, generator_loss=-1.3935, encoder_loss=0.1386
# Batch 150: variant_loss=1.3770, generator_loss=-1.3815, encoder_loss=0.1508
# Batch 160: variant_loss=1.3833, generator_loss=-1.3875, encoder_loss=0.1402
# Batch 170: variant_loss=1.3846, generator_loss=-1.3891, encoder_loss=0.1562
# Batch 180: variant_loss=1.3754, generator_loss=-1.3801, encoder_loss=0.1593
# Batch 190: variant_loss=1.3821, generator_loss=-1.3871, encoder_loss=0.1511
# Batch 200: variant_loss=1.3956, generator_loss=-1.4004, encoder_loss=0.1541
# Batch 210: variant_loss=1.3897, generator_loss=-1.3944, encoder_loss=0.1473
# Batch 220: variant_loss=1.3770, generator_loss=-1.3817, encoder_loss=0.1340
# Batch 230: variant_loss=1.3863, generator_loss=-1.3907, encoder_loss=0.1331
# Batch 240: variant_loss=1.3801, generator_loss=-1.3844, encoder_loss=0.1543
# Batch 250: variant_loss=1.3950, generator_loss=-1.3994, encoder_loss=0.1469
# Batch 260: variant_loss=1.3750, generator_loss=-1.3799, encoder_loss=0.1389
# Batch 270: variant_loss=1.3905, generator_loss=-1.3948, encoder_loss=0.1377
# Batch 280: variant_loss=1.3901, generator_loss=-1.3943, encoder_loss=0.1521
# Batch 290: variant_loss=1.3823, generator_loss=-1.3879, encoder_loss=0.1357
# Batch 300: variant_loss=1.3814, generator_loss=-1.3857, encoder_loss=0.1517
# Batch 310: variant_loss=1.3920, generator_loss=-1.3969, encoder_loss=0.1322
# Epoch 5 Averages:
# variant_loss: 1.3865
# generator_loss: -1.3911
# encoder_loss: 0.1470
# diversity_loss: -0.0455
# Saved checkpoint at ./checkpoints/epoch_5
# Epoch 6/100
# Batch 0: variant_loss=1.3837, generator_loss=-1.3879, encoder_loss=0.1326
# Batch 10: variant_loss=1.3843, generator_loss=-1.3895, encoder_loss=0.1450
# Batch 20: variant_loss=1.3902, generator_loss=-1.3946, encoder_loss=0.1323
# Batch 30: variant_loss=1.3788, generator_loss=-1.3836, encoder_loss=0.1495
# Batch 40: variant_loss=1.3789, generator_loss=-1.3840, encoder_loss=0.1501
# Batch 50: variant_loss=1.3832, generator_loss=-1.3868, encoder_loss=0.1530
# Batch 60: variant_loss=1.3816, generator_loss=-1.3857, encoder_loss=0.1336
# Batch 70: variant_loss=1.3858, generator_loss=-1.3902, encoder_loss=0.1615
# Batch 80: variant_loss=1.3984, generator_loss=-1.4027, encoder_loss=0.1475
# Batch 90: variant_loss=1.3858, generator_loss=-1.3902, encoder_loss=0.1360
# Batch 100: variant_loss=1.3910, generator_loss=-1.3960, encoder_loss=0.1420
# Batch 110: variant_loss=1.3950, generator_loss=-1.3998, encoder_loss=0.1538
# Batch 120: variant_loss=1.3842, generator_loss=-1.3894, encoder_loss=0.1376
# Batch 130: variant_loss=1.3944, generator_loss=-1.3993, encoder_loss=0.1536
# Batch 140: variant_loss=1.3829, generator_loss=-1.3884, encoder_loss=0.1371
# Batch 150: variant_loss=1.3935, generator_loss=-1.3987, encoder_loss=0.1422
# Batch 160: variant_loss=1.3865, generator_loss=-1.3912, encoder_loss=0.1355
# Batch 170: variant_loss=1.3855, generator_loss=-1.3902, encoder_loss=0.1520
# Batch 180: variant_loss=1.3849, generator_loss=-1.3892, encoder_loss=0.1598
# Batch 190: variant_loss=1.3907, generator_loss=-1.3949, encoder_loss=0.1566
# Batch 200: variant_loss=1.3895, generator_loss=-1.3941, encoder_loss=0.1595
# Batch 210: variant_loss=1.3820, generator_loss=-1.3867, encoder_loss=0.1377
# Batch 220: variant_loss=1.3941, generator_loss=-1.3990, encoder_loss=0.1406
# Batch 230: variant_loss=1.3930, generator_loss=-1.3983, encoder_loss=0.1553
# Batch 240: variant_loss=1.3893, generator_loss=-1.3949, encoder_loss=0.1523
# Batch 250: variant_loss=1.3862, generator_loss=-1.3911, encoder_loss=0.1514
# Batch 260: variant_loss=1.3885, generator_loss=-1.3933, encoder_loss=0.1307
# Batch 270: variant_loss=1.3853, generator_loss=-1.3904, encoder_loss=0.1381
# Batch 280: variant_loss=1.3917, generator_loss=-1.3967, encoder_loss=0.1531
# Batch 290: variant_loss=1.3869, generator_loss=-1.3921, encoder_loss=0.1580
# Batch 300: variant_loss=1.3801, generator_loss=-1.3857, encoder_loss=0.1513
# Batch 310: variant_loss=1.3864, generator_loss=-1.3913, encoder_loss=0.1350
# Epoch 6 Averages:
# variant_loss: 1.3871
# generator_loss: -1.3920
# encoder_loss: 0.1472
# diversity_loss: -0.0487
# Saved checkpoint at ./checkpoints/epoch_6
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 45s 134ms/step - accuracy: 0.5515 - loss: 1.7620 - val_accuracy: 0.8591 - val_loss: 0.5559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# Overall Accuracy: 0.8591
# Overall Precision: 0.8800
# Confusion Matrix:
# [[141   0   0 ...   0   0   0]
#  [  0  74   0 ...   0   5   0]
#  [  0   0 108 ...   0   0   0]
#  ...
#  [  0   0   0 ... 150   0   0]
#  [  0   0   0 ...   1 127   0]
#  [  0   0   0 ...   0   0 146]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#       Adposhel       0.99      0.98      0.98       144
#          Agent       0.96      0.62      0.75       120
#        Allaple       0.98      0.84      0.91       128
#  Alueron.gen!J       1.00      0.84      0.91        25
#      Amonetize       0.98      0.88      0.93       147
#         Androm       0.70      0.96      0.81       150
#        Autorun       0.39      0.85      0.54       146
#         Benign       0.83      0.69      0.75       208
#      BrowseFox       0.87      0.90      0.88       143
#    C2LOP.gen!g       0.93      1.00      0.96        25
# Dialplatform.B       1.00      1.00      1.00        25
#         Dinwod       0.96      0.91      0.93       149
#           Elex       0.88      0.98      0.93       150
#         Expiro       0.51      0.60      0.55       151
#       Fakerean       0.99      1.00      0.99        75
#         Fasong       0.99      0.99      0.99       150
#        HackKMS       0.97      0.99      0.98       149
#           Hlux       0.92      0.99      0.96       150
#       Injector       0.87      0.75      0.81       145
#    InstallCore       0.96      0.99      0.97       150
#     Lolyda.AA1       1.00      0.88      0.94        60
#     Lolyda.AA2       0.78      1.00      0.88        25
#      MultiPlug       0.94      0.85      0.89       149
#     Neoreklami       0.93      0.99      0.95       150
#         Neshta       0.61      0.41      0.49       147
#         Regrun       0.99      1.00      1.00       135
#         Sality       0.76      0.26      0.38       149
#      Snarasite       0.98      1.00      0.99       150
#      Stantinko       0.99      0.93      0.96       150
#            VBA       0.98      1.00      0.99       150
#        VBKrypt       0.86      0.87      0.86       146
#         Vilsel       1.00      1.00      1.00       146
#
#       accuracy                           0.86      4087
#      macro avg       0.89      0.87      0.87      4087
#   weighted avg       0.88      0.86      0.86      4087
#
# Epoch 6 Evaluation Metrics:
# Accuracy: 0.8591
# Precision: 0.8800
# Confusion Matrix:
# [[141   0   0 ...   0   0   0]
#  [  0  74   0 ...   0   5   0]
#  [  0   0 108 ...   0   0   0]
#  ...
#  [  0   0   0 ... 150   0   0]
#  [  0   0   0 ...   1 127   0]
#  [  0   0   0 ...   0   0 146]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#       Adposhel       0.99      0.98      0.98       144
#          Agent       0.96      0.62      0.75       120
#        Allaple       0.98      0.84      0.91       128
#  Alueron.gen!J       1.00      0.84      0.91        25
#      Amonetize       0.98      0.88      0.93       147
#         Androm       0.70      0.96      0.81       150
#        Autorun       0.39      0.85      0.54       146
#         Benign       0.83      0.69      0.75       208
#      BrowseFox       0.87      0.90      0.88       143
#    C2LOP.gen!g       0.93      1.00      0.96        25
# Dialplatform.B       1.00      1.00      1.00        25
#         Dinwod       0.96      0.91      0.93       149
#           Elex       0.88      0.98      0.93       150
#         Expiro       0.51      0.60      0.55       151
#       Fakerean       0.99      1.00      0.99        75
#         Fasong       0.99      0.99      0.99       150
#        HackKMS       0.97      0.99      0.98       149
#           Hlux       0.92      0.99      0.96       150
#       Injector       0.87      0.75      0.81       145
#    InstallCore       0.96      0.99      0.97       150
#     Lolyda.AA1       1.00      0.88      0.94        60
#     Lolyda.AA2       0.78      1.00      0.88        25
#      MultiPlug       0.94      0.85      0.89       149
#     Neoreklami       0.93      0.99      0.95       150
#         Neshta       0.61      0.41      0.49       147
#         Regrun       0.99      1.00      1.00       135
#         Sality       0.76      0.26      0.38       149
#      Snarasite       0.98      1.00      0.99       150
#      Stantinko       0.99      0.93      0.96       150
#            VBA       0.98      1.00      0.99       150
#        VBKrypt       0.86      0.87      0.86       146
#         Vilsel       1.00      1.00      1.00       146
#
#       accuracy                           0.86      4087
#      macro avg       0.89      0.87      0.87      4087
#   weighted avg       0.88      0.86      0.86      4087
#
# Epoch 7/100
# Batch 0: variant_loss=1.3888, generator_loss=-1.3936, encoder_loss=0.1636
# Batch 10: variant_loss=1.3857, generator_loss=-1.3912, encoder_loss=0.1350
# Batch 20: variant_loss=1.3840, generator_loss=-1.3893, encoder_loss=0.1411
# Batch 30: variant_loss=1.3922, generator_loss=-1.3972, encoder_loss=0.1564
# Batch 40: variant_loss=1.3972, generator_loss=-1.4033, encoder_loss=0.1393
# Batch 50: variant_loss=1.3875, generator_loss=-1.3924, encoder_loss=0.1543
# Batch 60: variant_loss=1.3857, generator_loss=-1.3903, encoder_loss=0.1565
# Batch 70: variant_loss=1.3860, generator_loss=-1.3908, encoder_loss=0.1586
# Batch 80: variant_loss=1.3876, generator_loss=-1.3930, encoder_loss=0.1548
# Batch 90: variant_loss=1.3868, generator_loss=-1.3926, encoder_loss=0.1362
# Batch 100: variant_loss=1.3894, generator_loss=-1.3948, encoder_loss=0.1404
# Batch 110: variant_loss=1.3755, generator_loss=-1.3805, encoder_loss=0.1471
# Batch 120: variant_loss=1.3813, generator_loss=-1.3868, encoder_loss=0.1500
# Batch 130: variant_loss=1.3870, generator_loss=-1.3915, encoder_loss=0.1574
# Batch 140: variant_loss=1.3871, generator_loss=-1.3922, encoder_loss=0.1413
# Batch 150: variant_loss=1.3989, generator_loss=-1.4036, encoder_loss=0.1509
# Batch 160: variant_loss=1.3882, generator_loss=-1.3943, encoder_loss=0.1597
# Batch 170: variant_loss=1.3929, generator_loss=-1.3981, encoder_loss=0.1607
# Batch 180: variant_loss=1.3919, generator_loss=-1.3969, encoder_loss=0.1287
# Batch 190: variant_loss=1.3929, generator_loss=-1.3978, encoder_loss=0.1242
# Batch 200: variant_loss=1.3811, generator_loss=-1.3862, encoder_loss=0.1522
# Batch 210: variant_loss=1.3936, generator_loss=-1.3986, encoder_loss=0.1614
# Batch 220: variant_loss=1.3880, generator_loss=-1.3931, encoder_loss=0.1514
# Batch 230: variant_loss=1.3922, generator_loss=-1.3980, encoder_loss=0.1373
# Batch 240: variant_loss=1.3784, generator_loss=-1.3840, encoder_loss=0.1604
# Batch 250: variant_loss=1.3801, generator_loss=-1.3858, encoder_loss=0.1423
# Batch 260: variant_loss=1.3830, generator_loss=-1.3879, encoder_loss=0.1426
# Batch 270: variant_loss=1.3819, generator_loss=-1.3873, encoder_loss=0.1409
# Batch 280: variant_loss=1.3782, generator_loss=-1.3833, encoder_loss=0.1507
# Batch 290: variant_loss=1.3844, generator_loss=-1.3902, encoder_loss=0.1533
# Batch 300: variant_loss=1.3867, generator_loss=-1.3922, encoder_loss=0.1474
# Batch 310: variant_loss=1.3944, generator_loss=-1.4001, encoder_loss=0.1470
# Epoch 7 Averages:
# variant_loss: 1.3865
# generator_loss: -1.3917
# encoder_loss: 0.1499
# diversity_loss: -0.0520
# Saved checkpoint at ./checkpoints/epoch_7
# Epoch 8/100
# Batch 0: variant_loss=1.3891, generator_loss=-1.3944, encoder_loss=0.1347
# Batch 10: variant_loss=1.3874, generator_loss=-1.3925, encoder_loss=0.1526
# Batch 20: variant_loss=1.3958, generator_loss=-1.4010, encoder_loss=0.1542
# Batch 30: variant_loss=1.3803, generator_loss=-1.3853, encoder_loss=0.1336
# Batch 40: variant_loss=1.3887, generator_loss=-1.3946, encoder_loss=0.1452
# Batch 50: variant_loss=1.3922, generator_loss=-1.3972, encoder_loss=0.1427
# Batch 60: variant_loss=1.3841, generator_loss=-1.3889, encoder_loss=0.1554
# Batch 70: variant_loss=1.3893, generator_loss=-1.3947, encoder_loss=0.1555
# Batch 80: variant_loss=1.3921, generator_loss=-1.3981, encoder_loss=0.1495
# Batch 90: variant_loss=1.3900, generator_loss=-1.3952, encoder_loss=0.1535
# Batch 100: variant_loss=1.3834, generator_loss=-1.3891, encoder_loss=0.1503
# Batch 110: variant_loss=1.3808, generator_loss=-1.3860, encoder_loss=0.1487
# Batch 120: variant_loss=1.3770, generator_loss=-1.3831, encoder_loss=0.1506
# Batch 130: variant_loss=1.3881, generator_loss=-1.3939, encoder_loss=0.1561
# Batch 140: variant_loss=1.3918, generator_loss=-1.3974, encoder_loss=0.1611
# Batch 150: variant_loss=1.4003, generator_loss=-1.4059, encoder_loss=0.1520
# Batch 160: variant_loss=1.3922, generator_loss=-1.3976, encoder_loss=0.1490
# Batch 170: variant_loss=1.3861, generator_loss=-1.3920, encoder_loss=0.1430
# Batch 180: variant_loss=1.3905, generator_loss=-1.3960, encoder_loss=0.1507
# Batch 190: variant_loss=1.3816, generator_loss=-1.3870, encoder_loss=0.1553
# Batch 200: variant_loss=1.3825, generator_loss=-1.3880, encoder_loss=0.1515
# Batch 210: variant_loss=1.3919, generator_loss=-1.3971, encoder_loss=0.1400
# Batch 220: variant_loss=1.3946, generator_loss=-1.3998, encoder_loss=0.1430
# Batch 230: variant_loss=1.3958, generator_loss=-1.4007, encoder_loss=0.1474
# Batch 240: variant_loss=1.3928, generator_loss=-1.3983, encoder_loss=0.1651
# Batch 250: variant_loss=1.3798, generator_loss=-1.3842, encoder_loss=0.1577
# Batch 260: variant_loss=1.3914, generator_loss=-1.3965, encoder_loss=0.1380
# Batch 270: variant_loss=1.3878, generator_loss=-1.3935, encoder_loss=0.1408
# Batch 280: variant_loss=1.4010, generator_loss=-1.4072, encoder_loss=0.1466
# Batch 290: variant_loss=1.3842, generator_loss=-1.3900, encoder_loss=0.1411
# Batch 300: variant_loss=1.3776, generator_loss=-1.3828, encoder_loss=0.1593
# Batch 310: variant_loss=1.3861, generator_loss=-1.3916, encoder_loss=0.1661
# Epoch 8 Averages:
# variant_loss: 1.3865
# generator_loss: -1.3920
# encoder_loss: 0.1491
# diversity_loss: -0.0545
# Saved checkpoint at ./checkpoints/epoch_8
# Epoch 9/100
# Batch 0: variant_loss=1.3869, generator_loss=-1.3922, encoder_loss=0.1542
# Batch 10: variant_loss=1.3901, generator_loss=-1.3956, encoder_loss=0.1526
# Batch 20: variant_loss=1.3885, generator_loss=-1.3943, encoder_loss=0.1373
# Batch 30: variant_loss=1.3880, generator_loss=-1.3934, encoder_loss=0.1576
# Batch 40: variant_loss=1.3895, generator_loss=-1.3944, encoder_loss=0.1701
# Batch 50: variant_loss=1.3839, generator_loss=-1.3894, encoder_loss=0.1545
# Batch 60: variant_loss=1.3816, generator_loss=-1.3870, encoder_loss=0.1454
# Batch 70: variant_loss=1.3977, generator_loss=-1.4029, encoder_loss=0.1525
# Batch 80: variant_loss=1.3746, generator_loss=-1.3795, encoder_loss=0.1318
# Batch 90: variant_loss=1.3873, generator_loss=-1.3920, encoder_loss=0.1455
# Batch 100: variant_loss=1.3845, generator_loss=-1.3899, encoder_loss=0.1599
# Batch 110: variant_loss=1.3772, generator_loss=-1.3824, encoder_loss=0.1517
# Batch 120: variant_loss=1.3735, generator_loss=-1.3795, encoder_loss=0.1515
# Batch 130: variant_loss=1.3911, generator_loss=-1.3969, encoder_loss=0.1442
# Batch 140: variant_loss=1.3912, generator_loss=-1.3969, encoder_loss=0.1467
# Batch 150: variant_loss=1.3976, generator_loss=-1.4035, encoder_loss=0.1770
# Batch 160: variant_loss=1.3888, generator_loss=-1.3953, encoder_loss=0.1490
# Batch 170: variant_loss=1.3847, generator_loss=-1.3905, encoder_loss=0.1618
# Batch 180: variant_loss=1.3855, generator_loss=-1.3912, encoder_loss=0.1644
# Batch 190: variant_loss=1.3964, generator_loss=-1.4029, encoder_loss=0.1549
# Batch 200: variant_loss=1.3937, generator_loss=-1.3992, encoder_loss=0.1468
# Batch 210: variant_loss=1.3852, generator_loss=-1.3899, encoder_loss=0.1449
# Batch 220: variant_loss=1.3825, generator_loss=-1.3883, encoder_loss=0.1541
# Batch 230: variant_loss=1.3918, generator_loss=-1.3975, encoder_loss=0.1417
# Batch 240: variant_loss=1.3858, generator_loss=-1.3914, encoder_loss=0.1582
# Batch 250: variant_loss=1.3924, generator_loss=-1.3979, encoder_loss=0.1515
# Batch 260: variant_loss=1.3849, generator_loss=-1.3909, encoder_loss=0.1557
# Batch 270: variant_loss=1.3874, generator_loss=-1.3932, encoder_loss=0.1391
# Batch 280: variant_loss=1.3931, generator_loss=-1.3986, encoder_loss=0.1491
# Batch 290: variant_loss=1.3881, generator_loss=-1.3932, encoder_loss=0.1592
# Batch 300: variant_loss=1.3861, generator_loss=-1.3910, encoder_loss=0.1449
# Batch 310: variant_loss=1.3794, generator_loss=-1.3848, encoder_loss=0.1389
# Epoch 9 Averages:
# variant_loss: 1.3867
# generator_loss: -1.3923
# encoder_loss: 0.1499
# diversity_loss: -0.0561
# Saved checkpoint at ./checkpoints/epoch_9
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 53s 160ms/step - accuracy: 0.6048 - loss: 1.5618 - val_accuracy: 0.8662 - val_loss: 0.5173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ...
# Batch 130: variant_loss=1.3870, generator_loss=-1.3928, encoder_loss=0.1657
# Batch 140: variant_loss=1.3911, generator_loss=-1.3977, encoder_loss=0.1376
# Batch 150: variant_loss=1.3916, generator_loss=-1.3972, encoder_loss=0.1468
# Batch 160: variant_loss=1.3768, generator_loss=-1.3827, encoder_loss=0.1641
# Batch 170: variant_loss=1.3697, generator_loss=-1.3751, encoder_loss=0.1542
# Batch 180: variant_loss=1.3897, generator_loss=-1.3948, encoder_loss=0.1528
# Batch 190: variant_loss=1.3871, generator_loss=-1.3929, encoder_loss=0.1616
# Batch 200: variant_loss=1.3957, generator_loss=-1.4018, encoder_loss=0.1437
# Batch 210: variant_loss=1.3874, generator_loss=-1.3930, encoder_loss=0.1707
# Batch 220: variant_loss=1.3797, generator_loss=-1.3859, encoder_loss=0.1444
# Batch 230: variant_loss=1.3817, generator_loss=-1.3880, encoder_loss=0.1559
# Batch 240: variant_loss=1.3914, generator_loss=-1.3974, encoder_loss=0.1709
# Batch 250: variant_loss=1.3882, generator_loss=-1.3947, encoder_loss=0.1545
# Batch 260: variant_loss=1.3846, generator_loss=-1.3913, encoder_loss=0.1475
# Batch 270: variant_loss=1.3842, generator_loss=-1.3902, encoder_loss=0.1677
# Batch 280: variant_loss=1.3838, generator_loss=-1.3904, encoder_loss=0.1641
# Batch 290: variant_loss=1.3894, generator_loss=-1.3955, encoder_loss=0.1600
# Batch 300: variant_loss=1.3834, generator_loss=-1.3892, encoder_loss=0.1456
# Batch 310: variant_loss=1.3918, generator_loss=-1.3977, encoder_loss=0.1437
# Epoch 15 Averages:
# variant_loss: 1.3863
# generator_loss: -1.3922
# encoder_loss: 0.1546
# diversity_loss: -0.0587
# Saved checkpoint at ./checkpoints/epoch_15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 47s 140ms/step - accuracy: 0.5684 - loss: 1.6875 - val_accuracy: 0.8466 - val_loss: 0.5557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# Overall Accuracy: 0.8466
# Overall Precision: 0.8667
# Confusion Matrix:
# [[140   0   0 ...   0   0   0]
#  [  0  78   2 ...   0   2   0]
#  [  0   0 117 ...   0   0   0]
#  ...
#  [  0   0   0 ... 150   0   0]
#  [  0   0   0 ...   0 130   0]
#  [  0   0   0 ...   0   0 146]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#       Adposhel       0.99      0.97      0.98       144
#          Agent       0.96      0.65      0.78       120
#        Allaple       0.79      0.91      0.84       128
#  Alueron.gen!J       0.93      1.00      0.96        25
#      Amonetize       0.99      0.87      0.93       147
#         Androm       0.43      0.97      0.60       150
#        Autorun       0.88      0.65      0.75       146
#         Benign       0.80      0.34      0.47       208
#      BrowseFox       0.83      0.80      0.82       143
#    C2LOP.gen!g       0.60      1.00      0.75        25
# Dialplatform.B       1.00      1.00      1.00        25
#         Dinwod       0.83      0.88      0.85       149
#           Elex       0.99      0.93      0.96       150
#         Expiro       0.74      0.68      0.71       151
#       Fakerean       1.00      0.99      0.99        75
#         Fasong       1.00      0.99      1.00       150
#        HackKMS       0.98      0.99      0.98       149
#           Hlux       0.90      0.99      0.94       150
#       Injector       0.87      0.64      0.74       145
#    InstallCore       0.99      0.99      0.99       150
#     Lolyda.AA1       0.95      1.00      0.98        60
#     Lolyda.AA2       1.00      1.00      1.00        25
#      MultiPlug       0.90      0.85      0.88       149
#     Neoreklami       0.95      0.99      0.97       150
#         Neshta       0.49      0.58      0.53       147
#         Regrun       0.88      1.00      0.94       135
#         Sality       0.62      0.40      0.49       149
#      Snarasite       1.00      1.00      1.00       150
#      Stantinko       0.81      0.99      0.89       150
#            VBA       0.97      1.00      0.99       150
#        VBKrypt       0.86      0.89      0.87       146
#         Vilsel       1.00      1.00      1.00       146
#
#       accuracy                           0.85      4087
#      macro avg       0.87      0.87      0.86      4087
#   weighted avg       0.87      0.85      0.84      4087
#
# Epoch 15 Evaluation Metrics:
# Accuracy: 0.8466
# Precision: 0.8667
# Confusion Matrix:
# [[140   0   0 ...   0   0   0]
#  [  0  78   2 ...   0   2   0]
#  [  0   0 117 ...   0   0   0]
#  ...
#  [  0   0   0 ... 150   0   0]
#  [  0   0   0 ...   0 130   0]
#  [  0   0   0 ...   0   0 146]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#       Adposhel       0.99      0.97      0.98       144
#          Agent       0.96      0.65      0.78       120
#        Allaple       0.79      0.91      0.84       128
#  Alueron.gen!J       0.93      1.00      0.96        25
#      Amonetize       0.99      0.87      0.93       147
#         Androm       0.43      0.97      0.60       150
#        Autorun       0.88      0.65      0.75       146
#         Benign       0.80      0.34      0.47       208
#      BrowseFox       0.83      0.80      0.82       143
#    C2LOP.gen!g       0.60      1.00      0.75        25
# Dialplatform.B       1.00      1.00      1.00        25
#         Dinwod       0.83      0.88      0.85       149
#           Elex       0.99      0.93      0.96       150
#         Expiro       0.74      0.68      0.71       151
#       Fakerean       1.00      0.99      0.99        75
#         Fasong       1.00      0.99      1.00       150
#        HackKMS       0.98      0.99      0.98       149
#           Hlux       0.90      0.99      0.94       150
#       Injector       0.87      0.64      0.74       145
#    InstallCore       0.99      0.99      0.99       150
#     Lolyda.AA1       0.95      1.00      0.98        60
#     Lolyda.AA2       1.00      1.00      1.00        25
#      MultiPlug       0.90      0.85      0.88       149
#     Neoreklami       0.95      0.99      0.97       150
#         Neshta       0.49      0.58      0.53       147
#         Regrun       0.88      1.00      0.94       135
#         Sality       0.62      0.40      0.49       149
#      Snarasite       1.00      1.00      1.00       150
#      Stantinko       0.81      0.99      0.89       150
#            VBA       0.97      1.00      0.99       150
#        VBKrypt       0.86      0.89      0.87       146
#         Vilsel       1.00      1.00      1.00       146
#
#       accuracy                           0.85      4087
#      macro avg       0.87      0.87      0.86      4087
#   weighted avg       0.87      0.85      0.84      4087
#
# Epoch 16/100
# Batch 0: variant_loss=1.3839, generator_loss=-1.3898, encoder_loss=0.1628
# Batch 10: variant_loss=1.3874, generator_loss=-1.3936, encoder_loss=0.1599
# Batch 20: variant_loss=1.3905, generator_loss=-1.3965, encoder_loss=0.1528
# Batch 30: variant_loss=1.3963, generator_loss=-1.4017, encoder_loss=0.1917
# Batch 40: variant_loss=1.4022, generator_loss=-1.4080, encoder_loss=0.1660
# Batch 50: variant_loss=1.3984, generator_loss=-1.4044, encoder_loss=0.1513
# Batch 60: variant_loss=1.3906, generator_loss=-1.3963, encoder_loss=0.1513
# Batch 70: variant_loss=1.3890, generator_loss=-1.3949, encoder_loss=0.1615
# Batch 80: variant_loss=1.3868, generator_loss=-1.3929, encoder_loss=0.1564
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fea3a486532f> in <cell line: 509>()
#     508
#     509 if __name__ == "__main__":
# --> 510     main()
#
# <ipython-input-2-fea3a486532f> in main()
#     442         for batch_idx, (images, labels) in enumerate(train_ds):
#     443             try:
# --> 444                 losses = model.train_step(images, labels)
#     445                 epoch_losses.append(losses)
#     446
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
